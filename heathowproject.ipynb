# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
heathow_87= pd.read_csv("heathow87.csv")

# %%
heathow_87
# Out:
#            Date  Daily Maximum Temperature (0900-0900) (C)  \
# 0    01/05/1987                                       17.2
# 1    02/05/1987                                       14.5
# 2    03/05/1987                                       10.1
# 3    04/05/1987                                       12.3
# 4    05/05/1987                                       14.2
# 5    06/05/1987                                       17.7
# 6    07/05/1987                                       17.6
# 7    08/05/1987                                       20.4
# 8    09/05/1987                                       23.7
# 9    10/05/1987                                       14.9
# 10   11/05/1987                                       15.2
# 11   12/05/1987                                       14.8
# 12   13/05/1987                                       13.8
# 13   14/05/1987                                       14.5
# 14   15/05/1987                                       12.3
# ...

# %%
heathow_87.plot.line(x="Date", y="Daily Maximum Temperature (0900-0900) (C)")
